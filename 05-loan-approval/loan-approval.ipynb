# %%
# Import libraries
import pandas as pd
import torch
from torch import nn

# %%
df = pd.read_csv("./data/loan_data.csv")

df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# 1                   0                   OWN     1000.0          EDUCATION
# 2                   3              MORTGAGE     5500.0            MEDICAL
# 3                   0                  RENT    35000.0            MEDICAL
# 4                   1                  RENT    35000.0            MEDICAL
# ...               ...                   ...        ...                ...
# 44995               6                  RENT    15000.0            MEDICAL
# 44996              17                  RENT     9000.0    HOMEIMPROVEMENT
# 44997               7                  RENT     2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT    12000.0          EDUCATION
# 44999               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 1              11.14                 0.08                         2.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 4              14.27                 0.53                         4.0
# ...              ...                  ...                         ...
# 44995          15.66                 0.31                         3.0
# 44996          14.07                 0.14                        11.0
# 44997          10.02                 0.05                        10.0
# 44998          13.23                 0.36                         6.0
# 44999          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 1               504                            Yes            0
# 2               635                             No            1
# 3               675                             No            1
# 4               586                             No            1
# ...             ...                            ...          ...
# 44995           645                             No            1
# 44996           621                             No            1
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1
#
# [45000 rows x 14 columns]

# %%
# Analyse columns: "person_income", "loan_intent", "loan_percent_income", "credit_score", "loan_status"

df = df[["person_income", "loan_intent", "loan_percent_income", "credit_score", "loan_status"]]

df
# Out:
#        person_income        loan_intent  loan_percent_income  credit_score  \
# 0            71948.0           PERSONAL                 0.49           561
# 1            12282.0          EDUCATION                 0.08           504
# 2            12438.0            MEDICAL                 0.44           635
# 3            79753.0            MEDICAL                 0.44           675
# 4            66135.0            MEDICAL                 0.53           586
# ...              ...                ...                  ...           ...
# 44995        47971.0            MEDICAL                 0.31           645
# 44996        65800.0    HOMEIMPROVEMENT                 0.14           621
# 44997        56942.0  DEBTCONSOLIDATION                 0.05           668
# 44998        33164.0          EDUCATION                 0.36           604
# 44999        51609.0  DEBTCONSOLIDATION                 0.13           628
#
#        loan_status
# 0                1
# 1                0
# 2                1
# 3                1
# 4                1
# ...            ...
# 44995            1
# 44996            1
# 44997            1
# 44998            1
# 44999            1
#
# [45000 rows x 5 columns]

# %%
# Define input and output
X = df[["person_income", "loan_intent", "loan_percent_income", "credit_score"]]

# Using get dummies to one hot-encode loan_intent column
X = pd.get_dummies(X, columns=["loan_intent"])

# %%
X.head()
# Out:
#    person_income  loan_percent_income  credit_score  \
# 0        71948.0                 0.49           561
# 1        12282.0                 0.08           504
# 2        12438.0                 0.44           635
# 3        79753.0                 0.44           675
# 4        66135.0                 0.53           586
#
#    loan_intent_DEBTCONSOLIDATION  loan_intent_EDUCATION  \
# 0                          False                  False
# 1                          False                   True
# 2                          False                  False
# 3                          False                  False
# 4                          False                  False
#
#    loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 0                        False                False                  True
# 1                        False                False                 False
# 2                        False                 True                 False
# 3                        False                 True                 False
# 4                        False                 True                 False
#
#    loan_intent_VENTURE
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False

# %%
# Define ouput
y = df["loan_status"]

# %%
y[0:5]
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: loan_status, dtype: int64

# %%
# Spliting dataset into train (70 %) and train (30 %)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#        person_income  loan_percent_income  credit_score  \
# 30159        41579.0                 0.14           647
# 6777         28052.0                 0.25           649
# 36563        63722.0                 0.11           626
# 11784        91870.0                 0.01           662
# 10370        29550.0                 0.34           633
#
#        loan_intent_DEBTCONSOLIDATION  loan_intent_EDUCATION  \
# 30159                          False                  False
# 6777                            True                  False
# 36563                          False                   True
# 11784                          False                  False
# 10370                           True                  False
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 30159                        False                 True                 False
# 6777                         False                False                 False
# 36563                        False                False                 False
# 11784                        False                False                  True
# 10370                        False                False                 False
#
#        loan_intent_VENTURE
# 30159                False
# 6777                 False
# 36563                False
# 11784                False
# 10370                False

# %%
# Normalizating input and output using StandardScaler
from sklearn.preprocessing import StandardScaler

scaler_X = StandardScaler()
X_train = scaler_X.fit_transform(X_train)
X_test = scaler_X.transform(X_test)

# scaler_Y = StandardScaler()
# y_train = scaler_Y.fit_transform(y_train.values.reshape(-1, 1))
# y_test = scaler_Y.transform(y_test.values.reshape(-1, 1))

# %%
# Transforming input and output into tensors for training
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train.values, dtype=torch.float32).reshape(-1, 1)

X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test.values, dtype=torch.float32).reshape(-1, 1)

# %%
# Define model
model = nn.Sequential(
    nn.Linear(9, 1)
)

# Define loss function
criterion = nn.BCEWithLogitsLoss()

# Define optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
from torch.utils.data import TensorDataset, DataLoader

# Define dataset
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

# Define dataloader
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
# Training loop
epochs = 100

for epoch in range(epochs):
    loss_sum = 0
    for X_batch, y_batch in train_dataloader:
        optimizer.zero_grad()
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)
        loss.backward()
        optimizer.step()

        loss_sum += loss.item()
    if epoch % 10 == 0:
        print(f"Loss: {loss_sum}")
# Out:
# Loss: 522.9163036346436
# Loss: 430.8007764071226
# Loss: 430.8242027312517
# Loss: 430.9209949821234
# Loss: 431.0659240037203
# Loss: 430.92247182130814
# Loss: 430.7633901387453
# Loss: 431.0243150740862
# Loss: 430.87934832274914
# Loss: 430.9517974406481

# %%
# Model evaluation
def evaluate_model(X, y):
    model.eval()
    with torch.no_grad():
        y_pred = nn.functional.sigmoid(model(X)) > 0.5
        
        # Calculate accuracy
        accuracy = (y_pred == y).type(torch.float32).mean()
        print(f"Accuracy: {accuracy * 100:.2f} %")

        # Calculate sensivity
        sensivity = (y_pred[y == 1] == y[y == 1]).type(torch.float32).mean()
        print(f"Sensivity: {sensivity * 100:.2f} %")

        # Calculate specifity
        specifity = (y_pred[y == 0] == y[y == 0]).type(torch.float32).mean()
        print(f"Specifity: {specifity * 100:.2f} %")

        # Calculate precision
        precision = (y_pred[y_pred == 1] == y[y_pred == 1]).type(torch.float32).mean()
        print(f"Precision: {precision * 100:.2f} %")

# %%
# Evalutation for train df
evaluate_model(X_train, y_train)
# Out:
# Accuracy: 81.79 %
# Sensivity: 31.26 %
# Specifity: 96.21 %
# Precision: 70.15 %

# %%
# Evalutation for test df
evaluate_model(X_test, y_test)
# Out:
# Accuracy: 81.33 %
# Sensivity: 30.13 %
# Specifity: 96.00 %
# Precision: 68.33 %
